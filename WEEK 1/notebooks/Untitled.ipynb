# %%
# Import the libraries we need
import requests        # for making API calls
import pandas as pd    # for data manipulation
import time            # to pause between API calls (respect rate limits)
import os              # for file path operations

# Confirm everything imported correctly
print("Libraries loaded successfully")
print(f"pandas version: {pd.__version__}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Import the libraries we need
#       2 import requests        # for making API calls
# ----> 3 import pandas as pd    # for data manipulation
#       4 import time            # to pause between API calls (respect rate limits)
#       5 import os              # for file path operations
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys
print(sys.executable)
